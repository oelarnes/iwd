# %%
import csv
import pandas as pd
import numpy as np
import sklearn

from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
reg = linear_model.LinearRegression()

np.set_printoptions(threshold=500)
pd.set_option('display.max_rows', 500)

# %%
path = './data/game_data_public.MKM.PremierDraft.csv'
with open(path) as csvfile:
    base_df = pd.read_csv(csvfile)

# %%
df = pd.DataFrame(base_df)
df = df[df['draft_time'] > '2024-02-19']

# %%
all_columns
# Out:
# ['expansion',
#  'event_type',
#  'draft_id',
#  'draft_time',
#  'game_time',
#  'build_index',
#  'match_number',
#  'game_number',
#  'rank',
#  'opp_rank',
#  'main_colors',
#  'splash_colors',
#  'on_play',
#  'num_mulligans',
#  'opp_num_mulligans',
#  'opp_colors',
#  'num_turns',
#  'won',
#  'opening_hand_A Killer Among Us',
#  'drawn_A Killer Among Us',
#  'tutored_A Killer Among Us',
#  'deck_A Killer Among Us',
#  'sideboard_A Killer Among Us',
#  'opening_hand_Absolving Lammasu',
#  'drawn_Absolving Lammasu',
#  'tutored_Absolving Lammasu',
#  'deck_Absolving Lammasu',
#  'sideboard_Absolving Lammasu',
#  'opening_hand_Aftermath Analyst',
#  'drawn_Aftermath Analyst',
#  'tutored_Aftermath Analyst',
#  'deck_Aftermath Analyst',
#  'sideboard_Aftermath Analyst',
#  'opening_hand_Agency Coroner',
#  'drawn_Agency Coroner',
#  'tutored_Agency Coroner',
#  'deck_Agency Coroner',
#  'sideboard_Agency Coroner',
#  'opening_hand_Agency Outfitter',
#  'drawn_Agency Outfitter',
#  'tutored_Agency Outfitter',
#  'deck_Agency Outfitter',
#  'sideboard_Agency Outfitter',
#  'opening_hand_Agrus Kos, Spirit of Justice',
#  'drawn_Agrus Kos, Spirit of Justice',
#  'tutored_Agrus Kos, Spirit of Justice',
#  'deck_Agrus Kos, Spirit of Justice',
#  'sideboard_Agrus Kos, Spirit of Justice',
#  'opening_hand_Airtight Alibi',
#  'drawn_Airtight Alibi',
#  'tutored_Airtight Alibi',
#  'deck_Airtight Alibi',
#  'sideboard_Airtight Alibi',
#  'opening_hand_Alley Assailant',
#  'drawn_Alley Assailant',
#  'tutored_Alley Assailant',
#  'deck_Alley Assailant',
#  'sideboard_Alley Assailant',
#  'opening_hand_Alquist Proft, Master Sleuth',
#  'drawn_Alquist Proft, Master Sleuth',
#  'tutored_Alquist Proft, Master Sleuth',
#  'deck_Alquist Proft, Master Sleuth',
#  'sideboard_Alquist Proft, Master Sleuth',
#  'opening_hand_Analyze the Pollen',
#  'drawn_Analyze the Pollen',
#  'tutored_Analyze the Pollen',
#  'deck_Analyze the Pollen',
#  'sideboard_Analyze the Pollen',
#  "opening_hand_Anzrag's Rampage",
#  "drawn_Anzrag's Rampage",
#  "tutored_Anzrag's Rampage",
#  "deck_Anzrag's Rampage",
#  "sideboard_Anzrag's Rampage",
#  'opening_hand_Anzrag, the Quake-Mole',
#  'drawn_Anzrag, the Quake-Mole',
#  'tutored_Anzrag, the Quake-Mole',
#  'deck_Anzrag, the Quake-Mole',
#  'sideboard_Anzrag, the Quake-Mole',
#  "opening_hand_Archdruid's Charm",
#  "drawn_Archdruid's Charm",
#  "tutored_Archdruid's Charm",
#  "deck_Archdruid's Charm",
#  "sideboard_Archdruid's Charm",
#  "opening_hand_Assassin's Trophy",
#  "drawn_Assassin's Trophy",
#  "tutored_Assassin's Trophy",
#  "deck_Assassin's Trophy",
#  "sideboard_Assassin's Trophy",
#  'opening_hand_Assemble the Players',
#  'drawn_Assemble the Players',
#  'tutored_Assemble the Players',
#  'deck_Assemble the Players',
#  'sideboard_Assemble the Players',
#  'opening_hand_Audience with Trostani',
#  'drawn_Audience with Trostani',
#  'tutored_Audience with Trostani',
#  'deck_Audience with Trostani',
#  'sideboard_Audience with Trostani',
#  "opening_hand_Aurelia's Vindicator",
#  "drawn_Aurelia's Vindicator",
#  "tutored_Aurelia's Vindicator",
#  "deck_Aurelia's Vindicator",
#  "sideboard_Aurelia's Vindicator",
#  'opening_hand_Aurelia, the Law Above',
#  'drawn_Aurelia, the Law Above',
#  'tutored_Aurelia, the Law Above',
#  'deck_Aurelia, the Law Above',
#  'sideboard_Aurelia, the Law Above',
#  'opening_hand_Auspicious Arrival',
#  'drawn_Auspicious Arrival',
#  'tutored_Auspicious Arrival',
#  'deck_Auspicious Arrival',
#  'sideboard_Auspicious Arrival',
#  'opening_hand_Axebane Ferox',
#  'drawn_Axebane Ferox',
#  'tutored_Axebane Ferox',
#  'deck_Axebane Ferox',
#  'sideboard_Axebane Ferox',
#  'opening_hand_Barbed Servitor',
#  'drawn_Barbed Servitor',
#  'tutored_Barbed Servitor',
#  'deck_Barbed Servitor',
#  'sideboard_Barbed Servitor',
#  'opening_hand_Basilica Stalker',
#  'drawn_Basilica Stalker',
#  'tutored_Basilica Stalker',
#  'deck_Basilica Stalker',
#  'sideboard_Basilica Stalker',
#  'opening_hand_Behind the Mask',
#  'drawn_Behind the Mask',
#  'tutored_Behind the Mask',
#  'deck_Behind the Mask',
#  'sideboard_Behind the Mask',
#  'opening_hand_Benthic Criminologists',
#  'drawn_Benthic Criminologists',
#  'tutored_Benthic Criminologists',
#  'deck_Benthic Criminologists',
#  'sideboard_Benthic Criminologists',
#  'opening_hand_Bishop of the Bloodstained',
#  'drawn_Bishop of the Bloodstained',
#  'tutored_Bishop of the Bloodstained',
#  'deck_Bishop of the Bloodstained',
#  'sideboard_Bishop of the Bloodstained',
#  'opening_hand_Bite Down on Crime',
#  'drawn_Bite Down on Crime',
#  'tutored_Bite Down on Crime',
#  'deck_Bite Down on Crime',
#  'sideboard_Bite Down on Crime',
#  'opening_hand_Blood Spatter Analysis',
#  'drawn_Blood Spatter Analysis',
#  'tutored_Blood Spatter Analysis',
#  'deck_Blood Spatter Analysis',
#  'sideboard_Blood Spatter Analysis',
#  'opening_hand_Bolrac-Clan Basher',
#  'drawn_Bolrac-Clan Basher',
#  'tutored_Bolrac-Clan Basher',
#  'deck_Bolrac-Clan Basher',
#  'sideboard_Bolrac-Clan Basher',
#  'opening_hand_Branch of Vitu-Ghazi',
#  'drawn_Branch of Vitu-Ghazi',
#  'tutored_Branch of Vitu-Ghazi',
#  'deck_Branch of Vitu-Ghazi',
#  'sideboard_Branch of Vitu-Ghazi',
#  'opening_hand_Break Out',
#  'drawn_Break Out',
#  'tutored_Break Out',
#  'deck_Break Out',
#  'sideboard_Break Out',
#  'opening_hand_Bubble Smuggler',
#  'drawn_Bubble Smuggler',
#  'tutored_Bubble Smuggler',
#  'deck_Bubble Smuggler',
#  'sideboard_Bubble Smuggler',
#  'opening_hand_Burden of Guilt',
#  'drawn_Burden of Guilt',
#  'tutored_Burden of Guilt',
#  'deck_Burden of Guilt',
#  'sideboard_Burden of Guilt',
#  'opening_hand_Burden of Proof',
#  'drawn_Burden of Proof',
#  'tutored_Burden of Proof',
#  'deck_Burden of Proof',
#  'sideboard_Burden of Proof',
#  'opening_hand_Buried in the Garden',
#  'drawn_Buried in the Garden',
#  'tutored_Buried in the Garden',
#  'deck_Buried in the Garden',
#  'sideboard_Buried in the Garden',
#  'opening_hand_Call a Surprise Witness',
#  'drawn_Call a Surprise Witness',
#  'tutored_Call a Surprise Witness',
#  'deck_Call a Surprise Witness',
#  'sideboard_Call a Surprise Witness',
#  'opening_hand_Candlestick',
#  'drawn_Candlestick',
#  'tutored_Candlestick',
#  'deck_Candlestick',
#  'sideboard_Candlestick',
#  'opening_hand_Case File Auditor',
#  'drawn_Case File Auditor',
#  'tutored_Case File Auditor',
#  'deck_Case File Auditor',
#  'sideboard_Case File Auditor',
#  'opening_hand_Case of the Burning Masks',
#  'drawn_Case of the Burning Masks',
#  'tutored_Case of the Burning Masks',
#  'deck_Case of the Burning Masks',
#  'sideboard_Case of the Burning Masks',
#  'opening_hand_Case of the Crimson Pulse',
#  'drawn_Case of the Crimson Pulse',
#  'tutored_Case of the Crimson Pulse',
#  'deck_Case of the Crimson Pulse',
#  'sideboard_Case of the Crimson Pulse',
#  'opening_hand_Case of the Filched Falcon',
#  'drawn_Case of the Filched Falcon',
#  'tutored_Case of the Filched Falcon',
#  'deck_Case of the Filched Falcon',
#  'sideboard_Case of the Filched Falcon',
#  'opening_hand_Case of the Gateway Express',
#  'drawn_Case of the Gateway Express',
#  'tutored_Case of the Gateway Express',
#  'deck_Case of the Gateway Express',
#  'sideboard_Case of the Gateway Express',
#  "opening_hand_Case of the Gorgon's Kiss",
#  "drawn_Case of the Gorgon's Kiss",
#  "tutored_Case of the Gorgon's Kiss",
#  "deck_Case of the Gorgon's Kiss",
#  "sideboard_Case of the Gorgon's Kiss",
#  'opening_hand_Case of the Locked Hothouse',
#  'drawn_Case of the Locked Hothouse',
#  'tutored_Case of the Locked Hothouse',
#  'deck_Case of the Locked Hothouse',
#  'sideboard_Case of the Locked Hothouse',
#  'opening_hand_Case of the Pilfered Proof',
#  'drawn_Case of the Pilfered Proof',
#  'tutored_Case of the Pilfered Proof',
#  'deck_Case of the Pilfered Proof',
#  'sideboard_Case of the Pilfered Proof',
#  'opening_hand_Case of the Ransacked Lab',
#  'drawn_Case of the Ransacked Lab',
#  'tutored_Case of the Ransacked Lab',
#  'deck_Case of the Ransacked Lab',
#  'sideboard_Case of the Ransacked Lab',
#  'opening_hand_Case of the Shattered Pact',
#  'drawn_Case of the Shattered Pact',
#  'tutored_Case of the Shattered Pact',
#  'deck_Case of the Shattered Pact',
#  'sideboard_Case of the Shattered Pact',
#  'opening_hand_Case of the Stashed Skeleton',
#  'drawn_Case of the Stashed Skeleton',
#  'tutored_Case of the Stashed Skeleton',
#  'deck_Case of the Stashed Skeleton',
#  'sideboard_Case of the Stashed Skeleton',
#  'opening_hand_Case of the Trampled Garden',
#  'drawn_Case of the Trampled Garden',
#  'tutored_Case of the Trampled Garden',
#  'deck_Case of the Trampled Garden',
#  'sideboard_Case of the Trampled Garden',
#  'opening_hand_Case of the Uneaten Feast',
#  'drawn_Case of the Uneaten Feast',
#  'tutored_Case of the Uneaten Feast',
#  'deck_Case of the Uneaten Feast',
#  'sideboard_Case of the Uneaten Feast',
#  'opening_hand_Caught Red-Handed',
#  'drawn_Caught Red-Handed',
#  'tutored_Caught Red-Handed',
#  'deck_Caught Red-Handed',
#  'sideboard_Caught Red-Handed',
#  'opening_hand_Cease // Desist',
#  'drawn_Cease // Desist',
#  'tutored_Cease // Desist',
#  'deck_Cease // Desist',
#  'sideboard_Cease // Desist',
#  'opening_hand_Cerebral Confiscation',
#  'drawn_Cerebral Confiscation',
#  'tutored_Cerebral Confiscation',
#  'deck_Cerebral Confiscation',
#  'sideboard_Cerebral Confiscation',
#  'opening_hand_Chalk Outline',
#  'drawn_Chalk Outline',
#  'tutored_Chalk Outline',
#  'deck_Chalk Outline',
#  'sideboard_Chalk Outline',
#  'opening_hand_Clandestine Meddler',
#  'drawn_Clandestine Meddler',
#  'tutored_Clandestine Meddler',
#  'deck_Clandestine Meddler',
#  'sideboard_Clandestine Meddler',
#  'opening_hand_Coerced to Kill',
#  'drawn_Coerced to Kill',
#  'tutored_Coerced to Kill',
#  'deck_Coerced to Kill',
#  'sideboard_Coerced to Kill',
#  'opening_hand_Cold Case Cracker',
#  'drawn_Cold Case Cracker',
#  'tutored_Cold Case Cracker',
#  'deck_Cold Case Cracker',
#  'sideboard_Cold Case Cracker',
#  'opening_hand_Combine Chrysalis',
#  'drawn_Combine Chrysalis',
#  'tutored_Combine Chrysalis',
#  'deck_Combine Chrysalis',
#  'sideboard_Combine Chrysalis',
#  'opening_hand_Commercial District',
#  'drawn_Commercial District',
#  'tutored_Commercial District',
#  'deck_Commercial District',
#  'sideboard_Commercial District',
#  'opening_hand_Concealed Weapon',
#  'drawn_Concealed Weapon',
#  'tutored_Concealed Weapon',
#  'deck_Concealed Weapon',
#  'sideboard_Concealed Weapon',
#  'opening_hand_Connecting the Dots',
#  'drawn_Connecting the Dots',
#  'tutored_Connecting the Dots',
#  'deck_Connecting the Dots',
#  'sideboard_Connecting the Dots',
#  'opening_hand_Consign // Oblivion',
#  'drawn_Consign // Oblivion',
#  'tutored_Consign // Oblivion',
#  'deck_Consign // Oblivion',
#  'sideboard_Consign // Oblivion',
#  'opening_hand_Conspiracy Unraveler',
#  'drawn_Conspiracy Unraveler',
#  'tutored_Conspiracy Unraveler',
#  'deck_Conspiracy Unraveler',
#  'sideboard_Conspiracy Unraveler',
#  'opening_hand_Convenient Target',
#  'drawn_Convenient Target',
#  'tutored_Convenient Target',
#  'deck_Convenient Target',
#  'sideboard_Convenient Target',
#  'opening_hand_Cornered Crook',
#  'drawn_Cornered Crook',
#  'tutored_Cornered Crook',
#  'deck_Cornered Crook',
#  'sideboard_Cornered Crook',
#  'opening_hand_Coveted Falcon',
#  'drawn_Coveted Falcon',
#  'tutored_Coveted Falcon',
#  'deck_Coveted Falcon',
#  'sideboard_Coveted Falcon',
#  'opening_hand_Crashing Footfalls',
#  'drawn_Crashing Footfalls',
#  'tutored_Crashing Footfalls',
#  'deck_Crashing Footfalls',
#  'sideboard_Crashing Footfalls',
#  'opening_hand_Crime Novelist',
#  'drawn_Crime Novelist',
#  'tutored_Crime Novelist',
#  'deck_Crime Novelist',
#  'sideboard_Crime Novelist',
#  'opening_hand_Crimestopper Sprite',
#  'drawn_Crimestopper Sprite',
#  'tutored_Crimestopper Sprite',
#  'deck_Crimestopper Sprite',
#  'sideboard_Crimestopper Sprite',
#  'opening_hand_Crowd-Control Warden',
#  'drawn_Crowd-Control Warden',
#  'tutored_Crowd-Control Warden',
#  'deck_Crowd-Control Warden',
#  'sideboard_Crowd-Control Warden',
#  'opening_hand_Cryptex',
#  'drawn_Cryptex',
#  'tutored_Cryptex',
#  'deck_Cryptex',
#  'sideboard_Cryptex',
#  'opening_hand_Cryptic Coat',
#  'drawn_Cryptic Coat',
#  'tutored_Cryptic Coat',
#  'deck_Cryptic Coat',
#  'sideboard_Cryptic Coat',
#  'opening_hand_Culvert Ambusher',
#  'drawn_Culvert Ambusher',
#  'tutored_Culvert Ambusher',
#  'deck_Culvert Ambusher',
#  'sideboard_Culvert Ambusher',
#  'opening_hand_Curious Cadaver',
#  'drawn_Curious Cadaver',
#  'tutored_Curious Cadaver',
#  'deck_Curious Cadaver',
#  'sideboard_Curious Cadaver',
#  'opening_hand_Curious Inquiry',
#  'drawn_Curious Inquiry',
#  'tutored_Curious Inquiry',
#  'deck_Curious Inquiry',
#  'sideboard_Curious Inquiry',
#  'opening_hand_Deadly Complication',
#  'drawn_Deadly Complication',
#  'tutored_Deadly Complication',
#  'deck_Deadly Complication',
#  'sideboard_Deadly Complication',
#  'opening_hand_Deadly Cover-Up',
#  'drawn_Deadly Cover-Up',
#  'tutored_Deadly Cover-Up',
#  'deck_Deadly Cover-Up',
#  'sideboard_Deadly Cover-Up',
#  'opening_hand_Deduce',
#  'drawn_Deduce',
#  'tutored_Deduce',
#  'deck_Deduce',
#  'sideboard_Deduce',
#  'opening_hand_Defenestrated Phantom',
#  'drawn_Defenestrated Phantom',
#  'tutored_Defenestrated Phantom',
#  'deck_Defenestrated Phantom',
#  'sideboard_Defenestrated Phantom',
#  'opening_hand_Delney, Streetwise Lookout',
#  'drawn_Delney, Streetwise Lookout',
#  'tutored_Delney, Streetwise Lookout',
#  'deck_Delney, Streetwise Lookout',
#  'sideboard_Delney, Streetwise Lookout',
#  'opening_hand_Demand Answers',
#  'drawn_Demand Answers',
#  'tutored_Demand Answers',
#  'deck_Demand Answers',
#  'sideboard_Demand Answers',
#  "opening_hand_Detective's Satchel",
#  "drawn_Detective's Satchel",
#  "tutored_Detective's Satchel",
#  "deck_Detective's Satchel",
#  "sideboard_Detective's Satchel",
#  'opening_hand_Dog Walker',
#  'drawn_Dog Walker',
#  'tutored_Dog Walker',
#  'deck_Dog Walker',
#  'sideboard_Dog Walker',
#  'opening_hand_Doorkeeper Thrull',
#  'drawn_Doorkeeper Thrull',
#  'tutored_Doorkeeper Thrull',
#  'deck_Doorkeeper Thrull',
#  'sideboard_Doorkeeper Thrull',
#  'opening_hand_Doppelgang',
#  'drawn_Doppelgang',
#  'tutored_Doppelgang',
#  'deck_Doppelgang',
#  'sideboard_Doppelgang',
#  'opening_hand_Drag the Canal',
#  'drawn_Drag the Canal',
#  'tutored_Drag the Canal',
#  'deck_Drag the Canal',
#  'sideboard_Drag the Canal',
#  'opening_hand_Dramatic Accusation',
#  'drawn_Dramatic Accusation',
#  'tutored_Dramatic Accusation',
#  'deck_Dramatic Accusation',
#  'sideboard_Dramatic Accusation',
#  'opening_hand_Drown in the Loch',
#  'drawn_Drown in the Loch',
#  'tutored_Drown in the Loch',
#  'deck_Drown in the Loch',
#  'sideboard_Drown in the Loch',
#  'opening_hand_Due Diligence',
#  'drawn_Due Diligence',
#  'tutored_Due Diligence',
#  'deck_Due Diligence',
#  'sideboard_Due Diligence',
#  'opening_hand_Duskmantle, House of Shadow',
#  'drawn_Duskmantle, House of Shadow',
#  'tutored_Duskmantle, House of Shadow',
#  'deck_Duskmantle, House of Shadow',
#  'sideboard_Duskmantle, House of Shadow',
#  'opening_hand_Elegant Parlor',
#  'drawn_Elegant Parlor',
#  'tutored_Elegant Parlor',
#  'deck_Elegant Parlor',
#  'sideboard_Elegant Parlor',
#  'opening_hand_Eliminate the Impossible',
#  'drawn_Eliminate the Impossible',
#  'tutored_Eliminate the Impossible',
#  'deck_Eliminate the Impossible',
#  'sideboard_Eliminate the Impossible',
#  'opening_hand_Enlisted Wurm',
#  'drawn_Enlisted Wurm',
#  'tutored_Enlisted Wurm',
#  'deck_Enlisted Wurm',
#  'sideboard_Enlisted Wurm',
#  'opening_hand_Escape Tunnel',
#  'drawn_Escape Tunnel',
#  'tutored_Escape Tunnel',
#  'deck_Escape Tunnel',
#  'sideboard_Escape Tunnel',
#  'opening_hand_Essence of Antiquity',
#  'drawn_Essence of Antiquity',
#  'tutored_Essence of Antiquity',
#  'deck_Essence of Antiquity',
#  'sideboard_Essence of Antiquity',
#  'opening_hand_Etrata, Deadly Fugitive',
#  'drawn_Etrata, Deadly Fugitive',
#  'tutored_Etrata, Deadly Fugitive',
#  'deck_Etrata, Deadly Fugitive',
#  'sideboard_Etrata, Deadly Fugitive',
#  'opening_hand_Evidence Examiner',
#  'drawn_Evidence Examiner',
#  'tutored_Evidence Examiner',
#  'deck_Evidence Examiner',
#  'sideboard_Evidence Examiner',
#  'opening_hand_Evolutionary Leap',
#  'drawn_Evolutionary Leap',
#  'tutored_Evolutionary Leap',
#  'deck_Evolutionary Leap',
#  'sideboard_Evolutionary Leap',
#  'opening_hand_Exit Specialist',
#  'drawn_Exit Specialist',
#  'tutored_Exit Specialist',
#  'deck_Exit Specialist',
#  'sideboard_Exit Specialist',
#  'opening_hand_Expedited Inheritance',
#  'drawn_Expedited Inheritance',
#  'tutored_Expedited Inheritance',
#  'deck_Expedited Inheritance',
#  'sideboard_Expedited Inheritance',
#  'opening_hand_Expose the Culprit',
#  'drawn_Expose the Culprit',
#  'tutored_Expose the Culprit',
#  'deck_Expose the Culprit',
#  'sideboard_Expose the Culprit',
#  'opening_hand_Extract a Confession',
#  'drawn_Extract a Confession',
#  'tutored_Extract a Confession',
#  'deck_Extract a Confession',
#  'sideboard_Extract a Confession',
#  'opening_hand_Ezrim, Agency Chief',
#  'drawn_Ezrim, Agency Chief',
#  'tutored_Ezrim, Agency Chief',
#  'deck_Ezrim, Agency Chief',
#  'sideboard_Ezrim, Agency Chief',
#  'opening_hand_Fabricate',
#  'drawn_Fabricate',
#  'tutored_Fabricate',
#  'deck_Fabricate',
#  'sideboard_Fabricate',
#  'opening_hand_Fae Flight',
#  'drawn_Fae Flight',
#  'tutored_Fae Flight',
#  'deck_Fae Flight',
#  'sideboard_Fae Flight',
#  'opening_hand_Faerie Snoop',
#  'drawn_Faerie Snoop',
#  'tutored_Faerie Snoop',
#  'deck_Faerie Snoop',
#  'sideboard_Faerie Snoop',
#  'opening_hand_Fanatical Strength',
#  'drawn_Fanatical Strength',
#  'tutored_Fanatical Strength',
#  'deck_Fanatical Strength',
#  'sideboard_Fanatical Strength',
#  'opening_hand_Felonious Rage',
#  'drawn_Felonious Rage',
#  'tutored_Felonious Rage',
#  'deck_Felonious Rage',
#  'sideboard_Felonious Rage',
#  'opening_hand_Festerleech',
#  'drawn_Festerleech',
#  'tutored_Festerleech',
#  'deck_Festerleech',
#  'sideboard_Festerleech',
#  'opening_hand_Field of the Dead',
#  'drawn_Field of the Dead',
#  'tutored_Field of the Dead',
#  'deck_Field of the Dead',
#  'sideboard_Field of the Dead',
#  'opening_hand_Flotsam // Jetsam',
#  'drawn_Flotsam // Jetsam',
#  'tutored_Flotsam // Jetsam',
#  'deck_Flotsam // Jetsam',
#  'sideboard_Flotsam // Jetsam',
#  'opening_hand_Flourishing Bloom-Kin',
#  'drawn_Flourishing Bloom-Kin',
#  'tutored_Flourishing Bloom-Kin',
#  'deck_Flourishing Bloom-Kin',
#  'sideboard_Flourishing Bloom-Kin',
#  'opening_hand_Forensic Gadgeteer',
#  'drawn_Forensic Gadgeteer',
#  'tutored_Forensic Gadgeteer',
#  'deck_Forensic Gadgeteer',
#  'sideboard_Forensic Gadgeteer',
#  'opening_hand_Forensic Researcher',
#  'drawn_Forensic Researcher',
#  'tutored_Forensic Researcher',
#  'deck_Forensic Researcher',
#  'sideboard_Forensic Researcher',
#  'opening_hand_Forest',
#  'drawn_Forest',
#  'tutored_Forest',
#  'deck_Forest',
#  'sideboard_Forest',
#  'opening_hand_Forum Familiar',
#  'drawn_Forum Familiar',
#  'tutored_Forum Familiar',
#  'deck_Forum Familiar',
#  'sideboard_Forum Familiar',
#  'opening_hand_Frantic Scapegoat',
#  'drawn_Frantic Scapegoat',
#  'tutored_Frantic Scapegoat',
#  'deck_Frantic Scapegoat',
#  'sideboard_Frantic Scapegoat',
#  'opening_hand_Fugitive Codebreaker',
#  'drawn_Fugitive Codebreaker',
#  'tutored_Fugitive Codebreaker',
#  'deck_Fugitive Codebreaker',
#  'sideboard_Fugitive Codebreaker',
#  'opening_hand_Furtive Courier',
#  'drawn_Furtive Courier',
#  'tutored_Furtive Courier',
#  'deck_Furtive Courier',
#  'sideboard_Furtive Courier',
#  'opening_hand_Fuss // Bother',
#  'drawn_Fuss // Bother',
#  'tutored_Fuss // Bother',
#  'deck_Fuss // Bother',
#  'sideboard_Fuss // Bother',
#  'opening_hand_Gadget Technician',
#  'drawn_Gadget Technician',
#  'tutored_Gadget Technician',
#  'deck_Gadget Technician',
#  'sideboard_Gadget Technician',
#  'opening_hand_Galvanize',
#  'drawn_Galvanize',
#  'tutored_Galvanize',
#  'deck_Galvanize',
#  'sideboard_Galvanize',
#  'opening_hand_Gamble',
#  'drawn_Gamble',
#  'tutored_Gamble',
#  'deck_Gamble',
#  'sideboard_Gamble',
#  'opening_hand_Gearbane Orangutan',
#  'drawn_Gearbane Orangutan',
#  'tutored_Gearbane Orangutan',
#  'deck_Gearbane Orangutan',
#  'sideboard_Gearbane Orangutan',
#  'opening_hand_Get a Leg Up',
#  'drawn_Get a Leg Up',
#  'tutored_Get a Leg Up',
#  'deck_Get a Leg Up',
#  'sideboard_Get a Leg Up',
#  'opening_hand_Ghost Quarter',
#  'drawn_Ghost Quarter',
#  'tutored_Ghost Quarter',
#  'deck_Ghost Quarter',
#  'sideboard_Ghost Quarter',
#  'opening_hand_Ghostly Prison',
#  'drawn_Ghostly Prison',
#  'tutored_Ghostly Prison',
#  'deck_Ghostly Prison',
#  'sideboard_Ghostly Prison',
#  'opening_hand_Gleaming Geardrake',
#  'drawn_Gleaming Geardrake',
#  'tutored_Gleaming Geardrake',
#  'deck_Gleaming Geardrake',
#  'sideboard_Gleaming Geardrake',
#  'opening_hand_Glint Weaver',
#  'drawn_Glint Weaver',
#  'tutored_Glint Weaver',
#  'deck_Glint Weaver',
#  'sideboard_Glint Weaver',
#  'opening_hand_Gnaw to the Bone',
#  'drawn_Gnaw to the Bone',
#  'tutored_Gnaw to the Bone',
#  'deck_Gnaw to the Bone',
#  'sideboard_Gnaw to the Bone',
#  'opening_hand_Goblin Maskmaker',
#  'drawn_Goblin Maskmaker',
#  'tutored_Goblin Maskmaker',
#  'deck_Goblin Maskmaker',
#  'sideboard_Goblin Maskmaker',
#  'opening_hand_Goblin Warchief',
#  'drawn_Goblin Warchief',
#  'tutored_Goblin Warchief',
#  'deck_Goblin Warchief',
#  'sideboard_Goblin Warchief',
#  'opening_hand_Granite Witness',
#  'drawn_Granite Witness',
#  'tutored_Granite Witness',
#  'deck_Granite Witness',
#  'sideboard_Granite Witness',
#  'opening_hand_Gravestone Strider',
#  'drawn_Gravestone Strider',
#  'tutored_Gravestone Strider',
#  'deck_Gravestone Strider',
#  'sideboard_Gravestone Strider',
#  'opening_hand_Greenbelt Radical',
#  'drawn_Greenbelt Radical',
#  'tutored_Greenbelt Radical',
#  'deck_Greenbelt Radical',
#  'sideboard_Greenbelt Radical',
#  'opening_hand_Griffnaut Tracker',
#  'drawn_Griffnaut Tracker',
#  'tutored_Griffnaut Tracker',
#  'deck_Griffnaut Tracker',
#  'sideboard_Griffnaut Tracker',
#  'opening_hand_Haazda Vigilante',
#  'drawn_Haazda Vigilante',
#  'tutored_Haazda Vigilante',
#  'deck_Haazda Vigilante',
#  'sideboard_Haazda Vigilante',
#  'opening_hand_Hard Evidence',
#  'drawn_Hard Evidence',
#  'tutored_Hard Evidence',
#  'deck_Hard Evidence',
#  'sideboard_Hard Evidence',
#  'opening_hand_Hard-Hitting Question',
#  'drawn_Hard-Hitting Question',
#  'tutored_Hard-Hitting Question',
#  'deck_Hard-Hitting Question',
#  'sideboard_Hard-Hitting Question',
#  'opening_hand_Harried Dronesmith',
#  'drawn_Harried Dronesmith',
#  'tutored_Harried Dronesmith',
#  'deck_Harried Dronesmith',
#  'sideboard_Harried Dronesmith',
#  'opening_hand_Hedge Maze',
#  'drawn_Hedge Maze',
#  'tutored_Hedge Maze',
#  'deck_Hedge Maze',
#  'sideboard_Hedge Maze',
#  'opening_hand_Hedge Whisperer',
#  'drawn_Hedge Whisperer',
#  'tutored_Hedge Whisperer',
#  'deck_Hedge Whisperer',
#  'sideboard_Hedge Whisperer',
#  'opening_hand_Hide in Plain Sight',
#  'drawn_Hide in Plain Sight',
#  'tutored_Hide in Plain Sight',
#  'deck_Hide in Plain Sight',
#  'sideboard_Hide in Plain Sight',
#  'opening_hand_High Alert',
#  'drawn_High Alert',
#  'tutored_High Alert',
#  'deck_High Alert',
#  'sideboard_High Alert',
#  'opening_hand_Homicide Investigator',
#  'drawn_Homicide Investigator',
#  'tutored_Homicide Investigator',
#  'deck_Homicide Investigator',
#  'sideboard_Homicide Investigator',
#  'opening_hand_Hotshot Investigators',
#  'drawn_Hotshot Investigators',
#  'tutored_Hotshot Investigators',
#  'deck_Hotshot Investigators',
#  'sideboard_Hotshot Investigators',
#  'opening_hand_Hunted Bonebrute',
#  'drawn_Hunted Bonebrute',
#  'tutored_Hunted Bonebrute',
#  'deck_Hunted Bonebrute',
#  'sideboard_Hunted Bonebrute',
#  'opening_hand_Hustle // Bustle',
#  'drawn_Hustle // Bustle',
#  'tutored_Hustle // Bustle',
#  'deck_Hustle // Bustle',
#  'sideboard_Hustle // Bustle',
#  'opening_hand_Ill-Timed Explosion',
#  'drawn_Ill-Timed Explosion',
#  'tutored_Ill-Timed Explosion',
#  'deck_Ill-Timed Explosion',
#  'sideboard_Ill-Timed Explosion',
#  'opening_hand_Illicit Masquerade',
#  'drawn_Illicit Masquerade',
#  'tutored_Illicit Masquerade',
#  'deck_Illicit Masquerade',
#  'sideboard_Illicit Masquerade',
#  'opening_hand_Incinerator of the Guilty',
#  'drawn_Incinerator of the Guilty',
#  'tutored_Incinerator of the Guilty',
#  'deck_Incinerator of the Guilty',
#  'sideboard_Incinerator of the Guilty',
#  'opening_hand_Innocent Bystander',
#  'drawn_Innocent Bystander',
#  'tutored_Innocent Bystander',
#  'deck_Innocent Bystander',
#  'sideboard_Innocent Bystander',
#  'opening_hand_Inside Source',
#  'drawn_Inside Source',
#  'tutored_Inside Source',
#  'deck_Inside Source',
#  'sideboard_Inside Source',
#  'opening_hand_Insidious Roots',
#  'drawn_Insidious Roots',
#  'tutored_Insidious Roots',
#  'deck_Insidious Roots',
#  'sideboard_Insidious Roots',
#  'opening_hand_Intrude on the Mind',
#  'drawn_Intrude on the Mind',
#  'tutored_Intrude on the Mind',
#  'deck_Intrude on the Mind',
#  'sideboard_Intrude on the Mind',
#  'opening_hand_Island',
#  'drawn_Island',
#  'tutored_Island',
#  'deck_Island',
#  'sideboard_Island',
#  "opening_hand_It Doesn't Add Up",
#  "drawn_It Doesn't Add Up",
#  "tutored_It Doesn't Add Up",
#  "deck_It Doesn't Add Up",
#  "sideboard_It Doesn't Add Up",
#  'opening_hand_Ixidor, Reality Sculptor',
#  'drawn_Ixidor, Reality Sculptor',
#  'tutored_Ixidor, Reality Sculptor',
#  'deck_Ixidor, Reality Sculptor',
#  'sideboard_Ixidor, Reality Sculptor',
#  'opening_hand_Izoni, Center of the Web',
#  'drawn_Izoni, Center of the Web',
#  'tutored_Izoni, Center of the Web',
#  'deck_Izoni, Center of the Web',
#  'sideboard_Izoni, Center of the Web',
#  'opening_hand_Jace, Wielder of Mysteries',
#  'drawn_Jace, Wielder of Mysteries',
#  'tutored_Jace, Wielder of Mysteries',
#  'deck_Jace, Wielder of Mysteries',
#  'sideboard_Jace, Wielder of Mysteries',
#  'opening_hand_Jaded Analyst',
#  'drawn_Jaded Analyst',
#  'tutored_Jaded Analyst',
#  'deck_Jaded Analyst',
#  'sideboard_Jaded Analyst',
#  'opening_hand_Judith, Carnage Connoisseur',
#  'drawn_Judith, Carnage Connoisseur',
#  'tutored_Judith, Carnage Connoisseur',
#  'deck_Judith, Carnage Connoisseur',
#  'sideboard_Judith, Carnage Connoisseur',
#  'opening_hand_Karlov Watchdog',
#  'drawn_Karlov Watchdog',
#  'tutored_Karlov Watchdog',
#  'deck_Karlov Watchdog',
#  'sideboard_Karlov Watchdog',
#  "opening_hand_Kaya, Spirits' Justice",
#  "drawn_Kaya, Spirits' Justice",
#  "tutored_Kaya, Spirits' Justice",
#  "deck_Kaya, Spirits' Justice",
#  "sideboard_Kaya, Spirits' Justice",
#  'opening_hand_Kellan, Inquisitive Prodigy',
#  'drawn_Kellan, Inquisitive Prodigy',
#  'tutored_Kellan, Inquisitive Prodigy',
#  'deck_Kellan, Inquisitive Prodigy',
#  'sideboard_Kellan, Inquisitive Prodigy',
#  'opening_hand_Knife',
#  'drawn_Knife',
#  'tutored_Knife',
#  'deck_Knife',
#  'sideboard_Knife',
#  'opening_hand_Kraul Whipcracker',
#  'drawn_Kraul Whipcracker',
#  'tutored_Kraul Whipcracker',
#  'deck_Kraul Whipcracker',
#  'sideboard_Kraul Whipcracker',
#  "opening_hand_Krenko's Buzzcrusher",
#  "drawn_Krenko's Buzzcrusher",
#  "tutored_Krenko's Buzzcrusher",
#  "deck_Krenko's Buzzcrusher",
#  "sideboard_Krenko's Buzzcrusher",
#  'opening_hand_Krenko, Baron of Tin Street',
#  'drawn_Krenko, Baron of Tin Street',
#  'tutored_Krenko, Baron of Tin Street',
#  'deck_Krenko, Baron of Tin Street',
#  'sideboard_Krenko, Baron of Tin Street',
#  'opening_hand_Krosan Tusker',
#  'drawn_Krosan Tusker',
#  'tutored_Krosan Tusker',
#  'deck_Krosan Tusker',
#  'sideboard_Krosan Tusker',
#  'opening_hand_Krovod Haunch',
#  'drawn_Krovod Haunch',
#  'tutored_Krovod Haunch',
#  'deck_Krovod Haunch',
#  'sideboard_Krovod Haunch',
#  'opening_hand_Kuldotha Rebirth',
#  'drawn_Kuldotha Rebirth',
#  'tutored_Kuldotha Rebirth',
#  'deck_Kuldotha Rebirth',
#  'sideboard_Kuldotha Rebirth',
#  "opening_hand_Kylox's Voltstrider",
#  "drawn_Kylox's Voltstrider",
#  "tutored_Kylox's Voltstrider",
#  "deck_Kylox's Voltstrider",
#  "sideboard_Kylox's Voltstrider",
#  'opening_hand_Kylox, Visionary Inventor',
#  'drawn_Kylox, Visionary Inventor',
#  'tutored_Kylox, Visionary Inventor',
#  'deck_Kylox, Visionary Inventor',
#  'sideboard_Kylox, Visionary Inventor',
#  'opening_hand_Laid to Rest',
#  'drawn_Laid to Rest',
#  'tutored_Laid to Rest',
#  'deck_Laid to Rest',
#  'sideboard_Laid to Rest',
#  'opening_hand_Lamplight Phoenix',
#  'drawn_Lamplight Phoenix',
#  'tutored_Lamplight Phoenix',
#  'deck_Lamplight Phoenix',
#  'sideboard_Lamplight Phoenix',
#  'opening_hand_Lazav, Wearer of Faces',
#  'drawn_Lazav, Wearer of Faces',
#  'tutored_Lazav, Wearer of Faces',
#  'deck_Lazav, Wearer of Faces',
#  'sideboard_Lazav, Wearer of Faces',
#  'opening_hand_Lead Pipe',
#  'drawn_Lead Pipe',
#  'tutored_Lead Pipe',
#  'deck_Lead Pipe',
#  'sideboard_Lead Pipe',
#  'opening_hand_Leering Onlooker',
#  'drawn_Leering Onlooker',
#  'tutored_Leering Onlooker',
#  'deck_Leering Onlooker',
#  'sideboard_Leering Onlooker',
#  'opening_hand_Leonin Relic-Warder',
#  'drawn_Leonin Relic-Warder',
#  'tutored_Leonin Relic-Warder',
#  'deck_Leonin Relic-Warder',
#  'sideboard_Leonin Relic-Warder',
#  'opening_hand_Leyline of the Guildpact',
#  'drawn_Leyline of the Guildpact',
#  'tutored_Leyline of the Guildpact',
#  'deck_Leyline of the Guildpact',
#  'sideboard_Leyline of the Guildpact',
#  'opening_hand_Lightning Helix',
#  'drawn_Lightning Helix',
#  'tutored_Lightning Helix',
#  'deck_Lightning Helix',
#  'sideboard_Lightning Helix',
#  'opening_hand_Living Conundrum',
#  'drawn_Living Conundrum',
#  'tutored_Living Conundrum',
#  'deck_Living Conundrum',
#  'sideboard_Living Conundrum',
#  'opening_hand_Long Goodbye',
#  'drawn_Long Goodbye',
#  'tutored_Long Goodbye',
#  'deck_Long Goodbye',
#  'sideboard_Long Goodbye',
#  'opening_hand_Lost in the Maze',
#  'drawn_Lost in the Maze',
#  'tutored_Lost in the Maze',
#  'deck_Lost in the Maze',
#  'sideboard_Lost in the Maze',
#  'opening_hand_Loxodon Eavesdropper',
#  'drawn_Loxodon Eavesdropper',
#  'tutored_Loxodon Eavesdropper',
#  'deck_Loxodon Eavesdropper',
#  'sideboard_Loxodon Eavesdropper',
#  'opening_hand_Lumbering Laundry',
#  'drawn_Lumbering Laundry',
#  'tutored_Lumbering Laundry',
#  'deck_Lumbering Laundry',
#  'sideboard_Lumbering Laundry',
#  'opening_hand_Lush Portico',
#  'drawn_Lush Portico',
#  'tutored_Lush Portico',
#  'deck_Lush Portico',
#  'sideboard_Lush Portico',
#  'opening_hand_Macabre Reconstruction',
#  'drawn_Macabre Reconstruction',
#  'tutored_Macabre Reconstruction',
#  'deck_Macabre Reconstruction',
#  'sideboard_Macabre Reconstruction',
#  'opening_hand_Magmaw',
#  'drawn_Magmaw',
#  'tutored_Magmaw',
#  'deck_Magmaw',
#  'sideboard_Magmaw',
#  'opening_hand_Magnetic Snuffler',
#  'drawn_Magnetic Snuffler',
#  'tutored_Magnetic Snuffler',
#  'deck_Magnetic Snuffler',
#  'sideboard_Magnetic Snuffler',
#  'opening_hand_Magnifying Glass',
#  'drawn_Magnifying Glass',
#  'tutored_Magnifying Glass',
#  'deck_Magnifying Glass',
#  'sideboard_Magnifying Glass',
#  'opening_hand_Make Your Move',
#  'drawn_Make Your Move',
#  'tutored_Make Your Move',
#  'deck_Make Your Move',
#  'sideboard_Make Your Move',
#  'opening_hand_Makeshift Binding',
#  'drawn_Makeshift Binding',
#  'tutored_Makeshift Binding',
#  'deck_Makeshift Binding',
#  'sideboard_Makeshift Binding',
#  'opening_hand_Marketwatch Phantom',
#  'drawn_Marketwatch Phantom',
#  'tutored_Marketwatch Phantom',
#  'deck_Marketwatch Phantom',
#  'sideboard_Marketwatch Phantom',
#  'opening_hand_Mass Hysteria',
#  'drawn_Mass Hysteria',
#  'tutored_Mass Hysteria',
#  'deck_Mass Hysteria',
#  'sideboard_Mass Hysteria',
#  'opening_hand_Massacre Girl, Known Killer',
#  'drawn_Massacre Girl, Known Killer',
#  'tutored_Massacre Girl, Known Killer',
#  'deck_Massacre Girl, Known Killer',
#  'sideboard_Massacre Girl, Known Killer',
#  'opening_hand_Maverick Thopterist',
#  'drawn_Maverick Thopterist',
#  ...]

# %%
all_columns = list(df.columns)
name_columns = [col for col in all_columns if 'drawn_' in col]
names = [n.split('_')[1] for n in name_columns]

name_gen = lambda x: [f'{x}_{name}' for name in names]

# %%
deck_counts
# Out:
# A Killer Among Us                 85120
# Absolving Lammasu                 12763
# Aftermath Analyst                 42906
# Agency Coroner                     6452
# Agency Outfitter                   7296
# Agrus Kos, Spirit of Justice      13030
# Airtight Alibi                    37163
# Alley Assailant                   44761
# Alquist Proft, Master Sleuth      10852
# Analyze the Pollen                23530
# Anzrag's Rampage                    125
# Anzrag, the Quake-Mole             9436
# Archdruid's Charm                 21504
# Assassin's Trophy                  8603
# Assemble the Players               8914
# Audience with Trostani             2931
# Aurelia's Vindicator              15032
# Aurelia, the Law Above            25795
# Auspicious Arrival               134968
# Axebane Ferox                     26164
# Barbed Servitor                    9139
# Basilica Stalker                  51137
# Behind the Mask                    3960
# Benthic Criminologists            19531
# Bishop of the Bloodstained          223
# Bite Down on Crime               162707
# Blood Spatter Analysis            11727
# Bolrac-Clan Basher                37911
# Branch of Vitu-Ghazi              26766
# Break Out                          2951
# Bubble Smuggler                   80924
# Burden of Guilt                     505
# Burden of Proof                   18984
# Buried in the Garden              65167
# Call a Surprise Witness           23724
# Candlestick                        6479
# Case File Auditor                 20917
# Case of the Burning Masks         46662
# Case of the Crimson Pulse         17098
# Case of the Filched Falcon        31130
# Case of the Gateway Express       60680
# Case of the Gorgon's Kiss          6136
# Case of the Locked Hothouse       24037
# Case of the Pilfered Proof        18887
# Case of the Ransacked Lab           261
# Case of the Shattered Pact        21063
# Case of the Stashed Skeleton      18931
# Case of the Trampled Garden       33374
# Case of the Uneaten Feast          1571
# Caught Red-Handed                  3291
# Cease // Desist                   15403
# Cerebral Confiscation              5192
# Chalk Outline                     32232
# Clandestine Meddler               26956
# Coerced to Kill                   55115
# Cold Case Cracker                124926
# Combine Chrysalis                  1803
# Commercial District               18566
# Concealed Weapon                  28208
# Connecting the Dots                8761
# Consign // Oblivion                2588
# Conspiracy Unraveler               2984
# Convenient Target                 16668
# Cornered Crook                    30617
# Coveted Falcon                    16567
# Crashing Footfalls                 2322
# Crime Novelist                    18085
# Crimestopper Sprite              102501
# Crowd-Control Warden             110928
# Cryptex                            3751
# Cryptic Coat                      29957
# Culvert Ambusher                  40112
# Curious Cadaver                   22827
# Curious Inquiry                    9779
# Deadly Complication               21610
# Deadly Cover-Up                   20580
# Deduce                            91590
# Defenestrated Phantom             36064
# Delney, Streetwise Lookout         8551
# Demand Answers                    27230
# Detective's Satchel               48409
# Dog Walker                       175988
# Doorkeeper Thrull                  4791
# Doppelgang                        34518
# Drag the Canal                    12788
# Dramatic Accusation               77852
# Drown in the Loch                   726
# Due Diligence                     36217
# Duskmantle, House of Shadow         175
# Elegant Parlor                    19500
# Eliminate the Impossible          41767
# Enlisted Wurm                      6173
# Escape Tunnel                    176396
# Essence of Antiquity              11929
# Etrata, Deadly Fugitive            9797
# Evidence Examiner                 60903
# Evolutionary Leap                   205
# Exit Specialist                   61611
# Expedited Inheritance               124
# Expose the Culprit                 2261
# Extract a Confession             119147
# Ezrim, Agency Chief               23309
# Fabricate                            59
# Fae Flight                        17588
# Faerie Snoop                      76358
# Fanatical Strength               102670
# Felonious Rage                    71470
# Festerleech                       30091
# Field of the Dead                   193
# Flotsam // Jetsam                 19909
# Flourishing Bloom-Kin             68860
# Forensic Gadgeteer                15251
# Forensic Researcher               48324
# Forest                          1822166
# Forum Familiar                    20161
# Frantic Scapegoat                 40775
# Fugitive Codebreaker              22864
# Furtive Courier                   37073
# Fuss // Bother                    69582
# Gadget Technician                125239
# Galvanize                        133479
# Gamble                              163
# Gearbane Orangutan                61045
# Get a Leg Up                      59975
# Ghost Quarter                       163
# Ghostly Prison                      761
# Gleaming Geardrake                45957
# Glint Weaver                      65225
# Gnaw to the Bone                    197
# Goblin Maskmaker                  56938
# Goblin Warchief                     360
# Granite Witness                  133983
# Gravestone Strider               125742
# Greenbelt Radical                 62694
# Griffnaut Tracker                 53854
# Haazda Vigilante                  88548
# Hard Evidence                      5362
# Hard-Hitting Question             63462
# Harried Dronesmith                36207
# Hedge Maze                        23527
# Hedge Whisperer                   38263
# Hide in Plain Sight               32108
# High Alert                          134
# Homicide Investigator             21384
# Hotshot Investigators             44857
# Hunted Bonebrute                  22283
# Hustle // Bustle                  19838
# Ill-Timed Explosion               24647
# Illicit Masquerade                 5181
# Incinerator of the Guilty         12385
# Innocent Bystander                94995
# Inside Source                    169872
# Insidious Roots                   30093
# Intrude on the Mind               13474
# Island                          1480547
# It Doesn't Add Up                  6574
# Ixidor, Reality Sculptor            445
# Izoni, Center of the Web          29266
# Jace, Wielder of Mysteries         1515
# Jaded Analyst                     74972
# Judith, Carnage Connoisseur       11548
# Karlov Watchdog                   47484
# Kaya, Spirits' Justice            11168
# Kellan, Inquisitive Prodigy       26331
# Knife                              7111
# Kraul Whipcracker                 39569
# Krenko's Buzzcrusher              19305
# Krenko, Baron of Tin Street       24236
# Krosan Tusker                      4227
# Krovod Haunch                     26648
# Kuldotha Rebirth                    884
# Kylox's Voltstrider                7060
# Kylox, Visionary Inventor           693
# Laid to Rest                        114
# Lamplight Phoenix                 24243
# Lazav, Wearer of Faces            17999
# Lead Pipe                          6301
# Leering Onlooker                  45110
# Leonin Relic-Warder                3874
# Leyline of the Guildpact           2245
# Lightning Helix                   48968
# Living Conundrum                   5198
# Long Goodbye                      46050
# Lost in the Maze                  20236
# Loxodon Eavesdropper             173362
# Lumbering Laundry                  4437
# Lush Portico                      21904
# Macabre Reconstruction            42326
# Magmaw                             2911
# Magnetic Snuffler                  4742
# Magnifying Glass                   8533
# Make Your Move                    59270
# Makeshift Binding                162293
# Marketwatch Phantom              151654
# Mass Hysteria                       124
# Massacre Girl, Known Killer        9916
# Maverick Thopterist                4296
# Meddling Youths                   35653
# Mentor of the Meek                 4204
# Metalspinner's Puzzleknot           593
# Meticulous Archive                19298
# Millstone                            69
# Mistveil Plains                     568
# Mistway Spy                       31394
# Molten Psyche                        84
# Monologue Tax                        34
# Mountain                        1595470
# Murder                            75158
# Museum Nightwatch                125602
# Mystery Key                        1257
# Neighborhood Guardian             67976
# Nervous Gardener                 175347
# Nightdrinker Moroii               29758
# Niv-Mizzet, Guildpact             10414
# No More Lies                      23831
# No Witnesses                      14195
# Not on My Watch                   33527
# Novice Inspector                 174976
# Nyx Weaver                         2895
# Offender at Large                113481
# Officious Interrogation            5826
# On the Job                       126440
# Out Cold                         112317
# Outrageous Robbery                15164
# Perimeter Enforcer                57831
# Person of Interest               145105
# Persuasive Interrogators          19129
# Pick Your Poison                  12770
# Plains                          1927809
# Polygraph Orb                      7554
# Pompous Gadabout                  18751
# Possibility Storm                    23
# Presumed Dead                     15763
# Private Eye                       44962
# Proft's Eidetic Memory            25209
# Projektor Inspector              151585
# Public Thoroughfare               93612
# Push // Pull                      46197
# Putrid Warrior                      914
# Pyrotechnic Performer             25536
# Quintorius, Field Historian         849
# Rakdos, Patron of Chaos           11787
# Rakish Scoundrel                  31509
# Ranger-Captain of Eos              1786
# Raucous Theater                   14789
# Reasonable Doubt                  78569
# Reckless Detective                67738
# Red Herring                      136371
# Reenact the Crime                   799
# Relive the Past                    2113
# Repeat Offender                   53077
# Repulsive Mutation                64432
# Riftburst Hellion                 82949
# Rope                               2695
# Rot Farm Mortipede                26107
# Rubblebelt Braggart               21469
# Rubblebelt Maverick              130569
# Rune-Brand Juggler                20421
# Sample Collector                  42929
# Sanctuary Wall                     9617
# Sanguine Savior                   82609
# Sanitation Automaton             139400
# Scene of the Crime                44668
# Seasoned Consultant              145072
# Shadowy Backstreet                16048
# Shady Informant                   37655
# Shard of Broken Glass               148
# Sharp-Eyed Rookie                 27474
# Shock                            141354
# Show and Tell                        89
# Slice from the Shadows            82878
# Slime Against Humanity             6491
# Slimy Dualleech                   28735
# Smuggler's Copter                  3095
# Snarling Gorehound                86221
# Soul Enervation                   34914
# Soul Search                        5880
# Spell Snare                         377
# Steamcore Scholar                 27813
# Stromkirk Captain                   695
# Sudden Setback                    14181
# Sumala Sentry                     46313
# Surveillance Monitor              55518
# Suspicious Detonation             42394
# Swamp                           1094727
# Syr Konrad, the Grim               3723
# Tenth District Hero               25297
# Teysa, Opulent Oligarch           23493
# The Chase Is On                   89824
# The Pride of Hull Clade            4085
# They Went This Way                74260
# Thinking Cap                      34520
# Thundering Falls                  18568
# Tin Street Gossip                 29250
# Tireless Tracker                   2618
# Tolsimir, Midnight's Light        25851
# Topiary Panther                  140502
# Torch the Witness                 66166
# Toxin Analysis                    42973
# Tragic Slip                        1182
# Treacherous Greed                  6276
# Treacherous Terrain                2627
# Trostani, Three Whispers          12510
# Tunnel Tipster                   153381
# Unauthorized Exit                 83515
# Undercity Eliminator              34544
# Undercity Sewers                  17800
# Undercover Crocodelf             105642
# Underground Mortuary              19812
# Undergrowth Recon                   229
# Unscrupulous Agent                87703
# Unyielding Gatekeeper             25003
# Urgent Necropsy                    9026
# Vannifar, Evolved Enigma          13346
# Vein Ripper                       11351
# Vengeful Creeper                 126112
# Vengeful Tracker                  45348
# Victimize                          1118
# Vitu-Ghazi Inspector             149095
# Warleader's Call                  24011
# Wispdrinker Vampire               31952
# Wojek Investigator                26732
# Worldsoul's Rage                  10611
# Worldspine Wurm                     398
# Wrench                             8456
# Yarus, Roar of the Old Gods       20942
# dtype: int64

# %%
deck_df = pd.DataFrame(df[name_gen('deck')])
deck_df.columns = names

deck_counts = deck_df.sum()
deck_counts.name = 'game counts'
deck_win_counts = deck_df[df['won']].sum()

gpwr = deck_win_counts / deck_counts
gpwr.name = 'gpwr'

# %%
oh_df = df[name_gen('opening_hand')]
oh_df.columns = names

drawn_df = df[name_gen('drawn')]
drawn_df.columns = names

ih_df = oh_df + drawn_df
ns_df = deck_df - ih_df
ns_df = ns_df.apply(lambda S: S.apply(lambda x: max(0, x)))

# %%
cards_seen = ih_df.sum(axis=1)
cards_seen.name = 'cards_seen'

# %%
gih_counts = ih_df.sum()
gih_win_counts = ih_df[df['won']].sum()

ns_counts = ns_df.sum()
ns_win_counts = ns_df[df['won']].sum()

gihwr = gih_win_counts / gih_counts
gihwr.name = 'gihwr'

gnswr = ns_win_counts / ns_counts
gnswr.name = 'gnswr'

# %%
ihd = gihwr - gpwr
ihd.name = 'in-hand delta'

# %%
gwih = ih_df.div(cards_seen, axis=0) * 40

# %%
gwihwr = gwih[df['won']].sum() / gwih.sum()
gwihwr.name = 'gwihwr'

# %%
gwihd = gwihwr - gpwr
gwihd.name = 'game-weighted in-hand delta'

# %%
deck_adjacency = deck_df.transpose().dot(deck_df)
average_marginal_decklist = deck_adjacency / deck_adjacency.sum()
d1gpwr = gpwr.dot(average_marginal_decklist)

d1d = gpwr - d1gpwr
d1d.name = 'distance-one delta'

# %%
ihd_df = pd.DataFrame([gpwr, ihd, gwihd, d1d, gihwr, gnswr, deck_counts])
# ihd_df.to_csv('ihd_df_6apr24.csv')

# %%
ih_analysis_df = pd.concat([deck_df, df[['won']], pd.DataFrame(cards_seen)], axis=1)

# %%
bias_map = {}
variance_map = {}
mean_map = {}
deck_gihwr = {}
deck_gnswr = {}

for name in names:
    filtered_df = ih_analysis_df[deck_df[name]>0]
    cards_seen_ar =  np.array(filtered_df['cards_seen'], dtype=np.double).reshape(filtered_df.shape[0], 1)
    cns_ar = 40 - cards_seen_ar
    won_ar = np.array(filtered_df['won'], dtype=np.double).reshape(filtered_df.shape[0], 1)
    filtered_deck_df = np.array(deck_df[name], dtype=np.double)[deck_df[name]>0].reshape(filtered_df.shape[0], 1)
    
    reg.fit(cards_seen_ar, won_ar)
    
    variance_map[name] = np.var(cards_seen_ar)
    mean_map[name] = np.mean(cards_seen_ar)
    bias_map[name] = reg.coef_[0][0]
    deck_gihwr[name] = np.sum(won_ar * cards_seen_ar * filtered_deck_df) / np.sum(cards_seen_ar * filtered_deck_df)
    deck_gnswr[name] = np.sum(won_ar * cns_ar * filtered_deck_df) / np.sum(cns_ar * filtered_deck_df)

# %%
bias = pd.Series(bias_map, index=names, name='cs bias')
var = pd.Series(variance_map, index=names, name='cs var')
mean = pd.Series(mean_map, index=names, name='cs mean')
deck_gihwr = pd.Series(deck_gihwr, index=names, name='deck gihwr')
deck_gnswr = pd.Series(deck_gnswr, index=names, name='deck gnswr')
bias_df = pd.DataFrame([bias, var, mean, deck_gihwr, deck_gnswr]).transpose()

# %%
bias_df['deck ihd form'] = bias_df['cs bias'] * bias_df['cs var'] / bias_df['cs mean']

# %%
metrics_df = pd.concat([ihd_df.transpose(), bias_df], axis=1)

# %%
metrics_df['deck ihd meas'] = metrics_df['deck gihwr'] - metrics_df['gpwr']
metrics_df['deck ihdd'] = metrics_df['deck ihd form'] - metrics_df['deck ihd meas']

# %%
metrics_df.to_csv('data/metrics_df_10apr24.csv')

# %%
metrics_df['deck ihd meas'].loc[[
    'Goblin Maskmaker', 
    'On the Job', 
    'Agrus Kos, Spirit of Justice', 
    'Inside Source', 
    'Makeshift Binding',
    'Tunnel Tipster',
    'Aftermath Analyst',
    'They Went This Way',
    "Detective's Satchel",
    'Chalk Outline'    
]]
# Out:
# Goblin Maskmaker               -0.011453
# On the Job                     -0.009962
# Agrus Kos, Spirit of Justice   -0.008741
# Inside Source                  -0.008718
# Makeshift Binding              -0.006270
# Tunnel Tipster                  0.002079
# Aftermath Analyst               0.008579
# They Went This Way              0.012142
# Detective's Satchel             0.016166
# Chalk Outline                   0.022859
# Name: deck ihd meas, dtype: float64

# %%
(final_df['in-hand delta'] / (final_df['in-hand delta'] - final_df['deck ihd meas']) < 0).sum()
# Out:
# 65

# %%
(final_df['in-hand delta'] / (final_df['in-hand delta'] - final_df['deck ihd meas']) > 2).sum() + \
(final_df['in-hand delta'] / (final_df['in-hand delta'] - final_df['deck ihd meas']) < 1/2).sum()
# Out:
# 146

# %%
final_df['deck ihd meas'].sort_values()
# Out:
# Mass Hysteria                  -0.014915
# Goblin Maskmaker               -0.011453
# Leonin Relic-Warder            -0.010624
# On the Job                     -0.009962
# Ranger-Captain of Eos          -0.009852
# Seasoned Consultant            -0.009809
# Frantic Scapegoat              -0.009567
# Neighborhood Guardian          -0.009558
# Felonious Rage                 -0.009403
# Marketwatch Phantom            -0.008958
# Agrus Kos, Spirit of Justice   -0.008741
# Lightning Helix                -0.008721
# Inside Source                  -0.008718
# Novice Inspector               -0.008626
# Ghostly Prison                 -0.008491
# Karlov Watchdog                -0.008299
# Perimeter Enforcer             -0.008015
# Due Diligence                  -0.007884
# Warleader's Call               -0.007865
# Case of the Gateway Express    -0.007837
# Dog Walker                     -0.007792
# Caught Red-Handed              -0.007271
# Haazda Vigilante               -0.007197
# Red Herring                    -0.007189
# Auspicious Arrival             -0.007143
# Meddling Youths                -0.007072
# Krovod Haunch                  -0.006568
# Museum Nightwatch              -0.006568
# Person of Interest             -0.006470
# Makeshift Binding              -0.006270
# Plains                         -0.005856
# Innocent Bystander             -0.005769
# Forum Familiar                 -0.005341
# Offender at Large              -0.005182
# Convenient Target              -0.004947
# Vengeful Tracker               -0.004912
# Pyrotechnic Performer          -0.004842
# Griffnaut Tracker              -0.004829
# Shock                          -0.004795
# The Chase Is On                -0.004730
# Call a Surprise Witness        -0.004719
# Tenth District Hero            -0.004718
# Wojek Investigator             -0.004535
# Putrid Warrior                 -0.004518
# Expose the Culprit             -0.004408
# Make Your Move                 -0.004332
# Defenestrated Phantom          -0.004196
# Delney, Streetwise Lookout     -0.004115
# Absolving Lammasu              -0.004102
# Unyielding Gatekeeper          -0.003641
# Assemble the Players           -0.003191
# Fuss // Bother                 -0.003116
# Mountain                       -0.002997
# Lamplight Phoenix              -0.002877
# Bolrac-Clan Basher             -0.002870
# Granite Witness                -0.002796
# Private Eye                    -0.002769
# Sumala Sentry                  -0.002725
# Concealed Weapon               -0.002608
# Case of the Burning Masks      -0.002592
# Bishop of the Bloodstained     -0.002483
# No More Lies                   -0.002415
# Doorkeeper Thrull              -0.002273
# Krenko, Baron of Tin Street    -0.002226
# Aurelia, the Law Above         -0.002177
# Knife                          -0.002164
# Galvanize                      -0.002063
# Gearbane Orangutan             -0.001960
# Crowd-Control Warden           -0.001898
# Not on My Watch                -0.001885
# Tolsimir, Midnight's Light     -0.001861
# Molten Psyche                  -0.001832
# Fugitive Codebreaker           -0.001792
# Sanitation Automaton           -0.001790
# Anzrag, the Quake-Mole         -0.001788
# Krenko's Buzzcrusher           -0.001775
# Aurelia's Vindicator           -0.001765
# Elegant Parlor                 -0.001634
# Essence of Antiquity           -0.001549
# Wrench                         -0.001481
# Ixidor, Reality Sculptor       -0.001475
# Sanguine Savior                -0.001264
# Reckless Detective             -0.001160
# Rubblebelt Braggart            -0.001141
# Connecting the Dots            -0.001063
# Lead Pipe                      -0.000879
# Kuldotha Rebirth               -0.000770
# Trostani, Three Whispers       -0.000721
# Vannifar, Evolved Enigma       -0.000695
# Torch the Witness              -0.000689
# Smuggler's Copter              -0.000641
# Break Out                      -0.000535
# Sanctuary Wall                 -0.000528
# Fanatical Strength             -0.000476
# Case of the Pilfered Proof     -0.000473
# Thinking Cap                    0.000013
# Demand Answers                  0.000035
# No Witnesses                    0.000210
# Hustle // Bustle                0.000263
# Magmaw                          0.000499
# Gadget Technician               0.000500
# Get a Leg Up                    0.000632
# Pompous Gadabout                0.000654
# Case File Auditor               0.000739
# Burden of Guilt                 0.000837
# Snarling Gorehound              0.001012
# Mentor of the Meek              0.001113
# Repeat Offender                 0.001285
# Rune-Brand Juggler              0.001374
# Crashing Footfalls              0.001412
# Case of the Trampled Garden     0.001447
# Ezrim, Agency Chief             0.001468
# Slimy Dualleech                 0.001589
# Ghost Quarter                   0.001631
# Clandestine Meddler             0.001657
# Mistveil Plains                 0.001763
# Airtight Alibi                  0.001777
# Harried Dronesmith              0.001896
# High Alert                      0.001951
# Axebane Ferox                   0.001985
# Shady Informant                 0.002003
# Hunted Bonebrute                0.002016
# Cornered Crook                  0.002064
# Tunnel Tipster                  0.002079
# Festerleech                     0.002226
# Unauthorized Exit               0.002234
# Incinerator of the Guilty       0.002236
# Wispdrinker Vampire             0.002285
# Cryptic Coat                    0.002386
# Yarus, Roar of the Old Gods     0.002402
# Kaya, Spirits' Justice          0.002498
# Lumbering Laundry               0.002502
# Hard-Hitting Question           0.002538
# Branch of Vitu-Ghazi            0.002563
# Soul Search                     0.002565
# Case of the Uneaten Feast       0.002591
# Tin Street Gossip               0.002672
# Nightdrinker Moroii             0.002684
# Burden of Proof                 0.002712
# Push // Pull                    0.002767
# Reasonable Doubt                0.002923
# Buried in the Garden            0.003008
# Deadly Complication             0.003092
# Hide in Plain Sight             0.003097
# Riftburst Hellion               0.003330
# Crimestopper Sprite             0.003582
# Teysa, Opulent Oligarch         0.003585
# Greenbelt Radical               0.003589
# Out Cold                        0.003644
# A Killer Among Us               0.003687
# Mistway Spy                     0.003730
# Expedited Inheritance           0.003780
# Case of the Stashed Skeleton    0.003853
# Toxin Analysis                  0.003953
# Lush Portico                    0.003966
# Suspicious Detonation           0.004121
# Case of the Crimson Pulse       0.004269
# Hard Evidence                   0.004309
# Sharp-Eyed Rookie               0.004322
# Curious Inquiry                 0.004460
# Bubble Smuggler                 0.004513
# Rope                            0.004545
# Alley Assailant                 0.004612
# Jaded Analyst                   0.004796
# Culvert Ambusher                0.004798
# Meticulous Archive              0.004833
# Flourishing Bloom-Kin           0.004908
# Officious Interrogation         0.004963
# Exit Specialist                 0.005003
# Lost in the Maze                0.005045
# Escape Tunnel                   0.005096
# Bite Down on Crime              0.005137
# Projektor Inspector             0.005182
# Forest                          0.005206
# Vein Ripper                     0.005257
# Cold Case Cracker               0.005268
# Fae Flight                      0.005270
# Long Goodbye                    0.005294
# Rubblebelt Maverick             0.005316
# Nervous Gardener                0.005342
# Sudden Setback                  0.005439
# Steamcore Scholar               0.005594
# Unscrupulous Agent              0.005622
# Slime Against Humanity          0.005639
# Vengeful Creeper                0.005653
# Island                          0.005721
# Archdruid's Charm               0.005857
# Tragic Slip                     0.005862
# Shadowy Backstreet              0.005931
# Case of the Gorgon's Kiss       0.006014
# Eliminate the Impossible        0.006028
# Slice from the Shadows          0.006083
# Enlisted Wurm                   0.006094
# Sample Collector                0.006149
# Vitu-Ghazi Inspector            0.006162
# Blood Spatter Analysis          0.006216
# Presumed Dead                   0.006295
# Swamp                           0.006314
# Case of the Filched Falcon      0.006356
# Alquist Proft, Master Sleuth    0.006356
# Analyze the Pollen              0.006424
# Massacre Girl, Known Killer     0.006430
# Basilica Stalker                0.006550
# Dramatic Accusation             0.006612
# Leering Onlooker                0.006652
# Pick Your Poison                0.006680
# Murder                          0.006829
# Izoni, Center of the Web        0.006864
# Gleaming Geardrake              0.006906
# Extract a Confession            0.006926
# Intrude on the Mind             0.006929
# Hotshot Investigators           0.006933
# Loxodon Eavesdropper            0.006946
# Undercover Crocodelf            0.006954
# Maverick Thopterist             0.006967
# Stromkirk Captain               0.006996
# Ill-Timed Explosion             0.007008
# Deduce                          0.007029
# Hedge Whisperer                 0.007223
# Commercial District             0.007234
# Thundering Falls                0.007448
# Gravestone Strider              0.007494
# Gamble                          0.007589
# Judith, Carnage Connoisseur     0.007694
# Topiary Panther                 0.007744
# Raucous Theater                 0.007847
# Kylox, Visionary Inventor       0.008056
# Homicide Investigator           0.008098
# Treacherous Greed               0.008184
# Worldsoul's Rage                0.008204
# Treacherous Terrain             0.008356
# Magnetic Snuffler               0.008441
# Scene of the Crime              0.008466
# Rakish Scoundrel                0.008489
# Aftermath Analyst               0.008579
# Syr Konrad, the Grim            0.008593
# Cerebral Confiscation           0.008617
# Candlestick                     0.008708
# Furtive Courier                 0.008726
# Crime Novelist                  0.008727
# Proft's Eidetic Memory          0.008781
# Undercity Eliminator            0.008816
# Glint Weaver                    0.008845
# Surveillance Monitor            0.008860
# Duskmantle, House of Shadow     0.009147
# Etrata, Deadly Fugitive         0.009226
# Kraul Whipcracker               0.009255
# Fabricate                       0.009294
# Tireless Tracker                0.009538
# Forensic Researcher             0.009648
# Leyline of the Guildpact        0.009752
# Spell Snare                     0.009758
# Forensic Gadgeteer              0.009948
# Soul Enervation                 0.010193
# Coveted Falcon                  0.010283
# Hedge Maze                      0.010301
# Agency Coroner                  0.010310
# Kellan, Inquisitive Prodigy     0.010399
# Monologue Tax                   0.010408
# Underground Mortuary            0.010649
# Repulsive Mutation              0.010694
# Deadly Cover-Up                 0.010751
# Behind the Mask                 0.010914
# Kylox's Voltstrider             0.010965
# Agency Outfitter                0.011222
# Public Thoroughfare             0.011233
# Metalspinner's Puzzleknot       0.011312
# Faerie Snoop                    0.011443
# Cease // Desist                 0.011588
# Case of the Shattered Pact      0.012045
# Assassin's Trophy               0.012070
# Reenact the Crime               0.012140
# They Went This Way              0.012142
# Illicit Masquerade              0.012167
# Macabre Reconstruction          0.012402
# Undercity Sewers                0.012659
# Krosan Tusker                   0.012866
# Rot Farm Mortipede              0.013004
# Goblin Warchief                 0.013034
# Benthic Criminologists          0.013132
# Conspiracy Unraveler            0.013134
# It Doesn't Add Up               0.013259
# Lazav, Wearer of Faces          0.013294
# Quintorius, Field Historian     0.013327
# Coerced to Kill                 0.013373
# Barbed Servitor                 0.013383
# Drag the Canal                  0.013550
# Flotsam // Jetsam               0.013703
# Case of the Locked Hothouse     0.013964
# Anzrag's Rampage                0.014000
# Evolutionary Leap               0.014061
# Relive the Past                 0.014193
# Consign // Oblivion             0.014279
# Laid to Rest                    0.014287
# Nyx Weaver                      0.014344
# Victimize                       0.014481
# Persuasive Interrogators        0.014649
# Outrageous Robbery              0.014700
# Rakdos, Patron of Chaos         0.014726
# Doppelgang                      0.014776
# Urgent Necropsy                 0.015126
# Magnifying Glass                0.015321
# Evidence Examiner               0.015334
# Drown in the Loch               0.015460
# Niv-Mizzet, Guildpact           0.015630
# Detective's Satchel             0.016166
# Undergrowth Recon               0.016307
# Insidious Roots                 0.016794
# Mystery Key                     0.017450
# Polygraph Orb                   0.018533
# Shard of Broken Glass           0.018552
# Jace, Wielder of Mysteries      0.018742
# Audience with Trostani          0.018743
# Cryptex                         0.020081
# The Pride of Hull Clade         0.020652
# Combine Chrysalis               0.020668
# Living Conundrum                0.020799
# Curious Cadaver                 0.022174
# Millstone                       0.022281
# Worldspine Wurm                 0.022840
# Chalk Outline                   0.022859
# Show and Tell                   0.027039
# Case of the Ransacked Lab       0.029990
# Field of the Dead               0.030033
# Possibility Storm               0.033242
# Gnaw to the Bone                0.038410
# Name: deck ihd meas, dtype: float64

# %%
(gihwr - final_df['deck ihd meas']).sort_values(ascending=False)
# Out:
# Aurelia's Vindicator            0.686756
# Izoni, Center of the Web        0.645229
# Agrus Kos, Spirit of Justice    0.639227
# Smuggler's Copter               0.638507
# Crashing Footfalls              0.637252
# Vein Ripper                     0.634888
# Tolsimir, Midnight's Light      0.633071
# Hide in Plain Sight             0.627272
# Cryptic Coat                    0.622725
# Ezrim, Agency Chief             0.622135
# Vannifar, Evolved Enigma        0.610549
# Teysa, Opulent Oligarch         0.610351
# Doppelgang                      0.607934
# Steamcore Scholar               0.605067
# Aurelia, the Law Above          0.603712
# Trostani, Three Whispers        0.602646
# Ill-Timed Explosion             0.602384
# Pyrotechnic Performer           0.597918
# Wojek Investigator              0.596587
# A Killer Among Us               0.595429
# Novice Inspector                0.595052
# Kellan, Inquisitive Prodigy     0.594322
# Kaya, Spirits' Justice          0.594037
# Torch the Witness               0.593919
# Lightning Helix                 0.593231
# Buried in the Garden            0.592795
# Enlisted Wurm                   0.592655
# Gleaming Geardrake              0.591909
# Tireless Tracker                0.591814
# Warleader's Call                0.591099
# Rakdos, Patron of Chaos         0.590553
# Lamplight Phoenix               0.587401
# Axebane Ferox                   0.586677
# Private Eye                     0.585023
# Repulsive Mutation              0.584878
# Reckless Detective              0.584663
# Fuss // Bother                  0.584333
# Person of Interest              0.583953
# Neighborhood Guardian           0.583123
# Urgent Necropsy                 0.583068
# Makeshift Binding               0.582090
# Tenth District Hero             0.581656
# Sharp-Eyed Rookie               0.580446
# Deadly Cover-Up                 0.580168
# Krenko, Baron of Tin Street     0.580002
# Perimeter Enforcer              0.579830
# Ranger-Captain of Eos           0.579315
# Hunted Bonebrute                0.578737
# Proft's Eidetic Memory          0.578113
# Unyielding Gatekeeper           0.577636
# Dog Walker                      0.577225
# Alquist Proft, Master Sleuth    0.575443
# Inside Source                   0.574750
# Case of the Gateway Express     0.574144
# Coerced to Kill                 0.572951
# Flourishing Bloom-Kin           0.572636
# Intrude on the Mind             0.571546
# Case of the Stashed Skeleton    0.571159
# Incinerator of the Guilty       0.568619
# Etrata, Deadly Fugitive         0.568522
# Shock                           0.568473
# Consign // Oblivion             0.567823
# Kraul Whipcracker               0.566415
# Sumala Sentry                   0.566178
# Maverick Thopterist             0.564991
# Detective's Satchel             0.564877
# Homicide Investigator           0.564091
# Blood Spatter Analysis          0.563901
# Glint Weaver                    0.563387
# Bite Down on Crime              0.562859
# Get a Leg Up                    0.562229
# Hard Evidence                   0.561682
# Evidence Examiner               0.561583
# Hard-Hitting Question           0.561426
# Felonious Rage                  0.560900
# Galvanize                       0.560881
# Long Goodbye                    0.559767
# Nervous Gardener                0.559563
# No More Lies                    0.559465
# Loxodon Eavesdropper            0.558617
# Fugitive Codebreaker            0.558389
# Exit Specialist                 0.558021
# On the Job                      0.557967
# Fanatical Strength              0.557819
# Offender at Large               0.557636
# Jace, Wielder of Mysteries      0.557246
# Seasoned Consultant             0.557091
# Granite Witness                 0.557083
# Greenbelt Radical               0.557006
# Lazav, Wearer of Faces          0.556600
# Reasonable Doubt                0.556557
# Red Herring                     0.556214
# Auspicious Arrival              0.555817
# Karlov Watchdog                 0.555607
# Yarus, Roar of the Old Gods     0.554977
# Marketwatch Phantom             0.554699
# Massacre Girl, Known Killer     0.554568
# Spell Snare                     0.554196
# The Chase Is On                 0.553309
# Goblin Maskmaker                0.553288
# Festerleech                     0.552724
# Rubblebelt Maverick             0.552117
# Gadget Technician               0.552025
# Frantic Scapegoat               0.552006
# Anzrag, the Quake-Mole          0.551890
# Projektor Inspector             0.551870
# Surveillance Monitor            0.551770
# Lush Portico                    0.551651
# Extract a Confession            0.551630
# Thundering Falls                0.551622
# Unauthorized Exit               0.551552
# Museum Nightwatch               0.551470
# Push // Pull                    0.551062
# Wispdrinker Vampire             0.550927
# Archdruid's Charm               0.550155
# Not on My Watch                 0.549188
# Vitu-Ghazi Inspector            0.548590
# Elegant Parlor                  0.548437
# Vengeful Creeper                0.548419
# Escape Tunnel                   0.548300
# Meddling Youths                 0.548280
# Leering Onlooker                0.548190
# Haazda Vigilante                0.547889
# Make Your Move                  0.547695
# Plains                          0.547080
# Lost in the Maze                0.546849
# Kylox's Voltstrider             0.546475
# Case of the Burning Masks       0.546070
# Underground Mortuary            0.546005
# Out Cold                        0.545880
# Tunnel Tipster                  0.545078
# Unscrupulous Agent              0.544960
# Murder                          0.543940
# Deduce                          0.543441
# Cold Case Cracker               0.543437
# Mountain                        0.543380
# Vengeful Tracker                0.543362
# Hedge Maze                      0.543201
# Crowd-Control Warden            0.543190
# Raucous Theater                 0.542336
# Sanguine Savior                 0.541640
# Krosan Tusker                   0.541530
# Putrid Warrior                  0.541168
# Bolrac-Clan Basher              0.540305
# Case of the Locked Hothouse     0.540147
# Rune-Brand Juggler              0.539753
# Topiary Panther                 0.539752
# Shadowy Backstreet              0.539673
# Forensic Researcher             0.539499
# Snarling Gorehound              0.539472
# Niv-Mizzet, Guildpact           0.539445
# Meticulous Archive              0.539144
# Victimize                       0.538917
# Undercity Sewers                0.538826
# Sanitation Automaton            0.538551
# Tin Street Gossip               0.538160
# Cornered Crook                  0.537936
# Analyze the Pollen              0.537752
# Drag the Canal                  0.537467
# Commercial District             0.537341
# Magmaw                          0.537212
# Island                          0.536506
# Slimy Dualleech                 0.536309
# Forest                          0.536194
# Audience with Trostani          0.535852
# Undercity Eliminator            0.535558
# Toxin Analysis                  0.535140
# Hotshot Investigators           0.535092
# Slice from the Shadows          0.534992
# Call a Surprise Witness         0.534751
# They Went This Way              0.534622
# Case File Auditor               0.534484
# Crimestopper Sprite             0.534262
# Leonin Relic-Warder             0.534118
# Deadly Complication             0.534060
# Krenko's Buzzcrusher            0.533717
# Cease // Desist                 0.533411
# Gamble                          0.533395
# Airtight Alibi                  0.533322
# Syr Konrad, the Grim            0.533022
# Eliminate the Impossible        0.532683
# Undercover Crocodelf            0.531869
# Case of the Trampled Garden     0.531788
# Show and Tell                   0.531785
# Scene of the Crime              0.531647
# Alley Assailant                 0.531437
# Sudden Setback                  0.530747
# Absolving Lammasu               0.530725
# Innocent Bystander              0.530679
# Treacherous Terrain             0.530437
# Mystery Key                     0.529995
# Riftburst Hellion               0.529603
# Krovod Haunch                   0.529202
# Faerie Snoop                    0.528532
# Aftermath Analyst               0.528459
# Soul Enervation                 0.528279
# Gravestone Strider              0.527461
# Sample Collector                0.527085
# Swamp                           0.526310
# Worldsoul's Rage                0.526077
# Drown in the Loch               0.525960
# Convenient Target               0.525574
# Defenestrated Phantom           0.525497
# Case of the Crimson Pulse       0.524435
# Hedge Whisperer                 0.524309
# Dramatic Accusation             0.523857
# Bubble Smuggler                 0.523848
# Caught Red-Handed               0.522735
# Case of the Filched Falcon      0.522333
# Nightdrinker Moroii             0.522149
# Pompous Gadabout                0.522106
# Due Diligence                   0.521973
# Clandestine Meddler             0.521690
# Presumed Dead                   0.521375
# No Witnesses                    0.520722
# Furtive Courier                 0.520700
# Culvert Ambusher                0.520565
# Gearbane Orangutan              0.520461
# Case of the Shattered Pact      0.519923
# Persuasive Interrogators        0.518984
# Essence of Antiquity            0.518436
# Nyx Weaver                      0.517503
# Repeat Offender                 0.517191
# Benthic Criminologists          0.517097
# Treacherous Greed               0.516482
# Doorkeeper Thrull               0.516002
# Soul Search                     0.515984
# Branch of Vitu-Ghazi            0.515365
# Burden of Proof                 0.515080
# Mistway Spy                     0.515074
# Jaded Analyst                   0.515065
# Pick Your Poison                0.514054
# Sanctuary Wall                  0.514001
# Ghostly Prison                  0.512814
# Basilica Stalker                0.512517
# Polygraph Orb                   0.512370
# Rubblebelt Braggart             0.511641
# Delney, Streetwise Lookout      0.511358
# Rot Farm Mortipede              0.511332
# Harried Dronesmith              0.511305
# Griffnaut Tracker               0.510666
# Rakish Scoundrel                0.510096
# Public Thoroughfare             0.510032
# Mistveil Plains                 0.509865
# Outrageous Robbery              0.509542
# Hustle // Bustle                0.508900
# Coveted Falcon                  0.508668
# Shady Informant                 0.508380
# Insidious Roots                 0.508054
# Fae Flight                      0.506665
# Macabre Reconstruction          0.506482
# Concealed Weapon                0.505734
# Tragic Slip                     0.504731
# Demand Answers                  0.504217
# Forum Familiar                  0.503478
# Chalk Outline                   0.503461
# Assassin's Trophy               0.502068
# Cryptex                         0.501740
# Wrench                          0.501040
# Mentor of the Meek              0.499710
# Curious Inquiry                 0.499405
# Suspicious Detonation           0.499386
# Forensic Gadgeteer              0.498870
# Lead Pipe                       0.498046
# Lumbering Laundry               0.497498
# Barbed Servitor                 0.495074
# Kuldotha Rebirth                0.494853
# Conspiracy Unraveler            0.494650
# Thinking Cap                    0.493903
# Agency Coroner                  0.493263
# Expose the Culprit              0.493057
# Case of the Gorgon's Kiss       0.492557
# Judith, Carnage Connoisseur     0.491602
# Candlestick                     0.491470
# Stromkirk Captain               0.491321
# Duskmantle, House of Shadow     0.490853
# Goblin Warchief                 0.490782
# Field of the Dead               0.490515
# Flotsam // Jetsam               0.489478
# Officious Interrogation         0.487978
# Crime Novelist                  0.485599
# Curious Cadaver                 0.484980
# Break Out                       0.484622
# The Pride of Hull Clade         0.484538
# Agency Outfitter                0.482708
# Illicit Masquerade              0.479093
# Knife                           0.478371
# Laid to Rest                    0.476623
# Case of the Pilfered Proof      0.475503
# High Alert                      0.472625
# Cerebral Confiscation           0.472116
# Combine Chrysalis               0.471906
# Mass Hysteria                   0.471437
# Assemble the Players            0.470634
# Behind the Mask                 0.470258
# Magnetic Snuffler               0.467229
# Connecting the Dots             0.462667
# It Doesn't Add Up               0.461723
# Relive the Past                 0.461513
# Rope                            0.456993
# Metalspinner's Puzzleknot       0.455105
# Shard of Broken Glass           0.452036
# Evolutionary Leap               0.449354
# Living Conundrum                0.448859
# Burden of Guilt                 0.444163
# Quintorius, Field Historian     0.443816
# Magnifying Glass                0.442286
# Slime Against Humanity          0.440136
# Case of the Uneaten Feast       0.429297
# Bishop of the Bloodstained      0.428015
# Worldspine Wurm                 0.422812
# Fabricate                       0.419278
# Leyline of the Guildpact        0.419070
# Ixidor, Reality Sculptor        0.415839
# Kylox, Visionary Inventor       0.413547
# Reenact the Crime               0.409372
# Gnaw to the Bone                0.377174
# Ghost Quarter                   0.375180
# Undergrowth Recon               0.357430
# Expedited Inheritance           0.329553
# Millstone                       0.319824
# Case of the Ransacked Lab       0.316784
# Monologue Tax                   0.283710
# Molten Psyche                   0.274559
# Anzrag's Rampage                0.256833
# Possibility Storm               0.197527
# dtype: float64
